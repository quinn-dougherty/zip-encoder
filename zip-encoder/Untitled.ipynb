# %%
#del(show_map, DF)
import altair as alt

from ze_tools import show_map

from toydat import DF

# %%
#show_map(sample_size=4000)
DF.head()
# Out:
#            TARGET     id    latitude   longitude  euclidean
# 0      functional  69572         NaN  functional  36.301755
# 1      functional   8776         NaN  functional  34.765155
# 2      functional  34310  functional         NaN  37.655065
# 3  non functional  67743         NaN         NaN  40.070254
# 4      functional  19728         NaN         NaN  31.184316

# %%
import numpy as np

#DF['euclidean'] = np.sqrt(DF.latitude ** 2 + DF.longitude ** 2)


# def rmv_outliers(df,column):
#     q1 = df[column].quantile(0.25)
#     q3 = df[column].quantile(0.75)
#     iqr = (df[column] >= q1) & (df[column] <= q3)
#     return df.loc[iqr]

# DF.latitude, DF.longitude = rmv_outliers(DF, 'latitude'), rmv_outliers(DF, 'longitude')

# DF.euclidean

DF[['latitude', 'longitude']]
# Out:
#              latitude                longitude
# 0                 NaN               functional
# 1                 NaN               functional
# 2          functional                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5          functional                      NaN
# 6      non functional           non functional
# 7      non functional                      NaN
# 8      non functional                      NaN
# 9                 NaN                      NaN
# 10         functional                      NaN
# 11                NaN               functional
# 12                NaN               functional
# 13                NaN               functional
# 14         functional               functional
# 15         functional                      NaN
# 16                NaN           non functional
# 17                NaN           non functional
# 18                NaN                      NaN
# ...

# %%
x = None
y = 1

x != None, y != None
# Out:
# (False, True)
